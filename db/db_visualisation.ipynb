# %%
from user_generator import user_generator
import pandas as pd

# %%
check_user = user_generator(50)
columns = ["dni", "nombre", "apellido_1", "apellido_2", "sexo", "edad", "comunidad_autonoma", "provincia", "pension", "grado_discapacidad", "estado_civil", "año_inicio_IMSERSO", "viajes_totales_IMSERSO", "viajes_2_ultimos_años", "canceled_trips_n3", "top_trip_last_year", "mean_score"]
df_check_users = pd.DataFrame(check_user, columns=columns)

df_check_users
# Out:
#          dni            nombre apellido_1 apellido_2    sexo  edad  \
# 0   22782411  FRANCISCO JAVIER    BENITEZ  CARNERERO  HOMBRE    81
# 1   78192316          MUHAMMAD    GUILLEN      MUÑOZ  HOMBRE    70
# 2   16631649            ALICIA  FERNANDEZ        HOZ   MUJER    76
# 3   88814496        MARIA JOSE       JUAN  FERNANDEZ   MUJER    81
# 4   35017415           ANTONIA      DURAN      RAMOS   MUJER    72
# 5   30944763          MERCEDES  FERNANDEZ      PEREZ   MUJER    90
# 6   40476002           ZENAIDA      VILLA    ALCAÑIZ   MUJER    71
# 7   81186335               ANA      LOPEZ      PEREZ   MUJER    67
# 8   25459330               ANA  FERNANDEZ       TORO   MUJER    74
# 9   76333665            VANESA      BOTIA    ALVAREZ   MUJER    70
# 10  58124370      MARIA TERESA      LUJAN    TOMILLO   MUJER    70
# 11  60829764        INMACULADA    HURTADO     JIMENO   MUJER    81
# 12  93244506             MARIA       NITU    LIÑEIRO   MUJER    68
# ...
