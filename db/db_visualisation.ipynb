# %%
from user_generator import user_generator
from hotel_generator import hotel_generator
import pandas as pd

# %%
check_user = user_generator(1)
columns = ["dni", "nombre", "apellido_1", "apellido_2", "sexo", "edad", "comunidad_autonoma", "provincia", "pension", "grado_discapacidad", "estado_civil", "año_inicio_IMSERSO", "viajes_totales_IMSERSO", "viajes_2_ultimos_años"]
df_check_users = pd.DataFrame(check_user, columns=columns)

df_check_users
# Out:
#         dni nombre apellido_1 apellido_2    sexo  edad comunidad_autonoma  \
# 0  84638256   LUIS     BORGES      PEREZ  HOMBRE    90      ILLES BALEARS
#
#        provincia  pension  grado_discapacidad estado_civil  \
# 0  ILLES BALEARS    450.0                   0       CASADX
#
#    año_inicio_IMSERSO  viajes_totales_IMSERSO  viajes_2_ultimos_años
# 0                2021                       1                      1

# %%
check_hotel = hotel_generator(3000)
columns = ["cif", "nombre", "C_Autonoma", "Provincia", "localidad", "estrellas", "telefono", "email", "movilidad_reducida", "piscina", "pension_completa","tipo_turismo","habitaciones"]
df_check_hotles = pd.DataFrame(check_hotel, columns=columns)

df_check_hotles.head(50)
# Out:
#           cif                                nombre C_Autonoma Provincia  \
# 0   F6558069I                 Balneario San Nicolás  Andalucía   Almería
# 1   C4509863G                         Avenida Hotel  Andalucía   Almería
# 2   R5188654N                        Hotel Catedral  Andalucía   Almería
# 3   L6102618A                         Hotel Almirez  Andalucía   Almería
# 4   C9979646N                     Hotel María Luisa  Andalucía     Cádiz
# 5   J2545622J               Hotel Mercure Algeciras  Andalucía     Cádiz
# 6   L3217544W                       La Fonda Califa  Andalucía     Cádiz
# 7   O1615283B                   Las Cortes de Cádiz  Andalucía     Cádiz
# 8   J5516861P                       Almadraba Conil  Andalucía     Cádiz
# 9   Z9337718F                          Alhaja Playa  Andalucía     Cádiz
# 10  N8742132E                         Hotel del Mar  Andalucía     Cádiz
# 11  R3850741Q                             Las Dunas  Andalucía     Cádiz
# ...
